# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect('./chinook.db')

# %%
cur = con.cursor()

# %%
cur.execute('SELECT * FROM Tracks')
data = cur.fetchall()
cur.description
# Out:
# (('TrackId', None, None, None, None, None, None),
#  ('Name', None, None, None, None, None, None),
#  ('AlbumId', None, None, None, None, None, None),
#  ('MediaTypeId', None, None, None, None, None, None),
#  ('GenreId', None, None, None, None, None, None),
#  ('Composer', None, None, None, None, None, None),
#  ('Milliseconds', None, None, None, None, None, None),
#  ('Bytes', None, None, None, None, None, None),
#  ('UnitPrice', None, None, None, None, None, None))

# %%
df = pd.DataFrame(data, columns= [x[0] for x in cur.description])

# %%
df
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %%
con = sqlite3.connect('./chinook.db')
cur = con.cursor()
cur.execute("SELECT tracks.Name AS Song, genres.Name AS Genre, playlists.Name AS Play_List FROM tracks, genres, playlist_track, playlists,albums, artists WHERE tracks.GenreId=genres.GenreId AND playlists.PlaylistId=playlist_track.PlaylistId AND tracks.TrackId=playlist_track.TrackId AND tracks.AlbumId=albums.AlbumId AND albums.ArtistId=artists.ArtistId")
data = cur.fetchall()
df = pd.DataFrame(data, columns= [x[0] for x in cur.description])

# %%
df['Genre'].value_counts()
# Out:
# Rock                  3238
# Latin                 1454
# Metal                  927
# Alternative & Punk     857
# Classical              334
# Jazz                   286
# Blues                  194
# TV Shows               186
# R&B/Soul               153
# Reggae                 144
# Drama                  128
# Hip Hop/Rap            105
# Soundtrack             103
# Pop                     96
# Alternative             92
# Electronica/Dance       71
# World                   58
# Heavy Metal             58
# Sci Fi & Fantasy        52
# Easy Listening          48
# Rock And Roll           36
# Comedy                  34
# Bossa Nova              30
# Science Fiction         26
# Opera                    5
# Name: Genre, dtype: int64
