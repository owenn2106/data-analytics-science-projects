# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"/Users/owenngimli/Desktop/BPD/data.csv")
df
# Out:
#          CrimeDate CrimeTime CrimeCode            Location  \
# 0       11/12/2016  02:35:00        3B   300 SAINT PAUL PL
# 1       11/12/2016  02:56:00       3CF      800 S BROADWAY
# 2       11/12/2016  03:00:00        6D    1500 PENTWOOD RD
# 3       11/12/2016  03:00:00        6D      6600 MILTON LN
# 4       11/12/2016  03:00:00        6E  300 W BALTIMORE ST
# ...            ...       ...       ...                 ...
# 285802  01/01/2011  22:15:00        4D     6800 MCCLEAN BD
# 285803  01/01/2011  22:30:00        6J    3000 ODONNELL ST
# 285804  01/01/2011  23:00:00        7A      2500 ARUNAH AV
# 285805  01/01/2011  23:25:00        4E     100 N MONROE ST
# 285806  01/01/2011  23:38:00        4D    800 N FREMONT AV
#
#                  Description Inside/Outside   Weapon   Post      District  \
# 0           ROBBERY - STREET              O      NaN  111.0       CENTRAL
# 1       ROBBERY - COMMERCIAL              I  FIREARM  213.0  SOUTHEASTERN
# ...

# %%
df.fillna('Not Registered', inplace=True)

# %%
df['CrimeDate'] = pd.to_datetime(df['CrimeDate'])

# %%
dateindex = df.set_index("CrimeDate")

# %%
monthly = dateindex.resample('M').count()
monthly.loc[monthly["Total Incidents"] == monthly["Total Incidents"].max()] #Most crime are done in july2015
# Out:
#             CrimeTime  CrimeCode  Location  Description  Inside/Outside  \
# CrimeDate
# 2015-07-31       4776       4776      4776         4776            4776
#
#             Weapon  Post  District  Neighborhood  Location 1  Total Incidents
# CrimeDate
# 2015-07-31    4776  4776      4776          4776        4776             4776

# %%
july15 = (df['CrimeDate'] >= '2015-07-01') & (df['CrimeDate'] <= '2015-07-31')
df.loc[july15]
# Out:
#        CrimeDate CrimeTime CrimeCode              Location        Description  \
# 62685 2015-07-31  21:30:00        6D      1300 KENHILL AVE  LARCENY FROM AUTO
# 62686 2015-07-31  21:30:00        6D        1300 LIMIT AVE  LARCENY FROM AUTO
# 62687 2015-07-31      2148        1F     4500 EDMONDSON AV           HOMICIDE
# 62688 2015-07-31  22:00:00        6E  3200 REISTERSTOWN RD            LARCENY
# 62689 2015-07-31  22:00:00        6J     3500 KENTUCKY AVE            LARCENY
# ...          ...       ...       ...                   ...                ...
# 67456 2015-07-01  23:00:00        4E        900 WICKLOW RD     COMMON ASSAULT
# 67457 2015-07-01  23:00:00        7A     2200 E MADISON ST         AUTO THEFT
# 67458 2015-07-01  23:15:00        4A       1600 DARLEY AVE       AGG. ASSAULT
# 67459 2015-07-01  23:57:00        6J       2000 HARFORD RD            LARCENY
# 67460 2015-07-01      2315        9S        1600 DARLEY AV           SHOOTING
#
# ...

# %%
df["Location"].value_counts()
# Out:
# Not Registered                  1623
# 200 E PRATT ST                   676
# 300 LIGHT ST                     603
# 1500 RUSSELL ST                  439
# 3200 TIOGA PW                    438
#                                 ...
# 5300 KENNISON AVE                  1
# 2900 ROCKWOOD AV                   1
# SMALLWOOD ST & WALBROOK AV         1
# 600 BLOCK FALLSWAY                 1
# 1300 ANGLESEA ST     #APT T3       1
# Name: Location, Length: 25950, dtype: int64

# %%
df['District'].value_counts()
# Out:
# NORTHEASTERN      44832
# SOUTHEASTERN      39245
# CENTRAL           33782
# SOUTHERN          33031
# NORTHERN          32005
# NORTHWESTERN      28690
# SOUTHWESTERN      26242
# EASTERN           24168
# WESTERN           23266
# NORTHESTERN         280
# SOUTHESTERN         205
# Not Registered       58
# Central               2
# Gay Street            1
# Name: District, dtype: int64

# %%
df["Neighborhood"].value_counts()
# Out:
# Downtown                   9666
# Frankford                  6791
# Belair-Edison              6133
# Brooklyn                   4528
# Cherry Hill                4273
#                            ...
# Mt Pleasant Park             12
# Blythewood                    5
# Dundalk Marine Terminal       1
# NORTHEASTERN                  1
# EASTERN                       1
# Name: Neighborhood, Length: 281, dtype: int64

# %%
last_6_months = (df['CrimeDate'] >= '2016-06-01') & (df['CrimeDate'] <= '2016-12-31')
last_6_months = df.loc[last_6_months].fillna('Not Registered')
last_6_months
# Out:
#        CrimeDate CrimeTime CrimeCode            Location  \
# 0     2016-11-12  02:35:00        3B   300 SAINT PAUL PL
# 1     2016-11-12  02:56:00       3CF      800 S BROADWAY
# 2     2016-11-12  03:00:00        6D    1500 PENTWOOD RD
# 3     2016-11-12  03:00:00        6D      6600 MILTON LN
# 4     2016-11-12  03:00:00        6E  300 W BALTIMORE ST
# ...          ...       ...       ...                 ...
# 23341 2016-06-01  21:30:00       3AF    1300 MADISON AVE
# 23342 2016-06-01  22:00:00        6D       400 S BOND ST
# 23343 2016-06-01  22:20:00        4E   1500 GUILFORD AVE
# 23344 2016-06-01  23:00:00        7A       800 LEMMON ST
# 23345 2016-06-01  23:48:00        4C         3800 3RD ST
#
#                 Description Inside/Outside          Weapon Post      District  \
# 0          ROBBERY - STREET              O  Not Registered  111       CENTRAL
# 1      ROBBERY - COMMERCIAL              I         FIREARM  213  SOUTHEASTERN
# ...

# %%
last_6_months['Location'].value_counts()
# Out:
# 1000 W PATAPSCO AVE    135
# 1500 RUSSELL ST         85
# Not Registered          82
# 6300 EASTERN AVE        61
# 2400 FREDERICK AVE      60
#                       ...
# 3900 PARKSIDE DR         1
# 600 S PAYSON ST          1
# 200 E 27TH ST            1
# 1100 S DECKER AVE        1
# 3800 LYNDALE AVE         1
# Name: Location, Length: 9027, dtype: int64

# %%
last_6_months['District'].value_counts()
# Out:
# NORTHEASTERN      3163
# SOUTHEASTERN      3074
# SOUTHERN          3027
# CENTRAL           2866
# NORTHERN          2547
# NORTHWESTERN      2336
# SOUTHWESTERN      2305
# EASTERN           2022
# WESTERN           1972
# SOUTHESTERN         13
# NORTHESTERN          9
# Not Registered       7
# Gay Street           1
# Name: District, dtype: int64

# %%
last_6_months['Neighborhood'].value_counts()
# Out:
# Downtown                840
# Brooklyn                518
# Frankford               517
# Belair-Edison           483
# Cherry Hill             478
#                        ...
# Villages Of Homeland      2
# Morgan Park               1
# Blythewood                1
# Port Covington            1
# EASTERN                   1
# Name: Neighborhood, Length: 277, dtype: int64

# %%
last_6_months['Weapon'].value_counts()
# Out:
# Not Registered    15082
# HANDS              3782
# FIREARM            2310
# OTHER              1309
# KNIFE               859
# Name: Weapon, dtype: int64

# %%
last_6_months.loc[last_6_months['Weapon'] == 'FIREARM',"Location"].value_counts()
# Out:
# 2200 W Cold Spring Ln      19
# 700 E PRESTON ST           16
# 400 FONTHILL AVE           13
# 1000 N MOUNT ST            12
# 800 W LEXINGTON ST         11
#                            ..
# 1900 CLIFTON AV             1
# 200 E READ ST               1
# PATAPSCO AV & LORENA AV     1
# 1500 ARGYLE AVE             1
# 1800 MARYLAND AVE           1
# Name: Location, Length: 1544, dtype: int64

# %%
last_6_months.loc[last_6_months['Weapon'] == 'FIREARM',"District"].value_counts()
# Out:
# NORTHEASTERN      312
# SOUTHERN          295
# SOUTHWESTERN      288
# CENTRAL           269
# NORTHERN          247
# EASTERN           232
# WESTERN           229
# SOUTHEASTERN      225
# NORTHWESTERN      211
# Not Registered      1
# SOUTHESTERN         1
# Name: District, dtype: int64

# %%
last_6_months.loc[last_6_months['Weapon'] == 'FIREARM',"Neighborhood"].value_counts()
# Out:
# Downtown               76
# Brooklyn               67
# Sandtown-Winchester    65
# Carrollton Ridge       58
# Belair-Edison          47
#                        ..
# South Baltimore         1
# Mayfield                1
# Seton Business Park     1
# Woodberry               1
# Fairmont                1
# Name: Neighborhood, Length: 239, dtype: int64

# %%
last_6_months['CrimeTime'].value_counts()
# Out:
# 18:00:00    597
# 17:00:00    531
# 22:00:00    523
# 20:00:00    523
# 21:00:00    496
#            ...
# 02:56:45      1
# 1505          1
# 05:41:00      1
# 1018          1
# 0520          1
# Name: CrimeTime, Length: 1838, dtype: int64
